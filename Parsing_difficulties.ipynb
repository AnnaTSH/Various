# %%
import wget
import time

# %% [markdown]
# В нашем проекте мы готовим обработанные датасеты из открытых данных портала "Трудвсем - Работа России". Они будут опубликованы на портале https://data-in.ru/ В первую очередь это датасеты вакансий и резюме. Но и другие справочники и общая статистика портала "Трудвсем". Они доступны здесь: https://trudvsem.ru/opendata/datasets

# %% [markdown]
# Кратко проблемы можно описать следующим образом: * файлы с интересующими нас данными очень большие (14Гб); * это xml-файлы.

# %% [markdown]
# С течением времени проект переформулировался в более амбициозную задачу - собрать все данные за 4 года, так как в каждом новом дампе (которые появляются на портале почти каждый день) старые резюме и вакансии удаляются, а они могли бы представлять интерес для исследователей.

# %% [markdown]
# Мы работаем в Яндекс-датасфере, мощности которой предоставляются нашей организации бесплатно, однако это не решает проблем с перегрузкой памяти, долгой загрузкой. Необходимо находить решения по оптимизации процесса.

# %% [markdown]
# Здесь сразу хочу сказать, что задача по распараллеливанию процессов загрузки файлов в датасферу, разархивации, парсинга ещё только в планах, однако её необходимо будет решить для того, чтобы ежеквартальное обновление проходило быстро и гладко с минимальным ручным вмешательством.

# %% [markdown]
# Вот для примера сколько занимает скачивание дампа (не требующего разархивации в данном случае) в датасферу

# %%
start_time = time.time()
wget.download('http://opendata.trudvsem.ru/7710538364-cv/data-20211125T194522-structure-20161130T143000.xml', 'resumes.xml')
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 501.4737253189087 seconds ---

# %% [markdown]
# Можем посмотреть небольшой кусок файла без скачивания целиком с помощью BeautifulSoup и urllib

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import lxml

# %%
data = urlopen('http://opendata.trudvsem.ru/7710538364-cv/data-20211125T194522-structure-20161130T143000.xml').read(5000).decode('utf8')

# %%
soup = BeautifulSoup(data, 'lxml-xml')
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <cvs vocab="http://schema.org/" xmlns:dc="http://purl.org/dc/terms/">
#  <cv about="http://opendata.trudvsem.ru/7710538364-cv/cv.xml#652be920-6f77-11eb-b531-ef76bd2a03c1" typeof="Person">
#   <region rel="dc:references" resource="http://opendata.trudvsem.ru/7710538364-regions/regions.xml#4200000000000"/>
#   <profession rel="dc:references" resource="http://opendata.trudvsem.ru/7710538364-professions/professions.xml#129014"/>
#   <industry rel="dc:references" resource="http://opendata.trudvsem.ru/7710538364-industries/industries.xml#Food"/>
#   <positionName property="jobTitle">
#    Кондитер
#   </positionName>
#   <creationDate>
#    2021-02-15
#   </creationDate>
#   <locality>
#    4200001200000
#   </locality>
#   <workExperienceList>
#    <workExperience>
#     <achievements>
#      &lt;p&gt;&lt;em&gt;изготовление конфет ручной работы, зефир, маршмелоу&lt;/em&gt;&lt;/p&gt;
#     </achievements>
#     <idOwner>
#      652be920-6f77-11eb-b531-ef76bd2a03c1
#     </idOwner>
#     <company_name>
#      ООО РОСТ
#     </company_name>
#     <dateTo>
#      2019-09-01T00:00:00+0300
#     </dateTo>
#     <jobTitle>
#      Кондитер
#     </jobTitle>
#     <type>
#      WorkExperience
#     </type>
#     <demands>
#      &lt;p&gt;Изготовление тортов, пироженых, печенья, десертов&lt;em&gt;&lt;span style="text-decoration: underline;"&gt;&lt;/span&gt;&lt;/em&gt;&lt;/p&gt;
#     </demands>
#     <dateFrom>
#      2017-08-01T00:00:00+0300
#     </dateFrom>
#    </workExperience>
#   </workExperienceList>
#   <educationType>
#    Среднее профессиональное
#   </educationType>
#   <educationList>
#    <educationType>
#     <qualification>
#      Технолог
#     </qualification>
#     <graduateYear>
#      2011
#     </graduateYear>
#     <idOwner>
#      652be920-6f77-11eb-b531-ef76bd2a03c1
#     </idOwner>
#     <type>
#      Education
#     </type>
#     <legalName>
#      Государственное учреждение среднего профессионального образования аграрный колледж поселок школьный Кемеровская область
#     </legalName>
#    </educationType>
#   </educationList>
#   <additionalEducationList/>
#   <worldskills>
#    <inspection_status>
#     Не применимо
#    </inspection_status>
#   </worldskills>
#   <competitions>
#    <abilympics/>
#   </competitions>
#   <qualification>
#    <nark/>
#   </qualification>
#   <driveLicenceList/>
#   <country>
#    <country_name>
#     Российская Федерация
#    </country_name>
#   </country>
#   <publishDate>
#    2021-02-16T05:09:52
#   </publishDate>
#   <scheduleTypesList>
#    <scheduleType>
#     Полный рабочий день
#    </scheduleType>
#   </scheduleTypesList>
#   <experience>
#    2
#   </experience>
#   <salary>
#    27000
#   </salary>
#   <busyType>
#    Полная занятость
#   </busyType>
#   <relocation>
#    Нет
#   </relocation>
#   <businessTrips>
#    Не готов к командировкам
#   </businessTrips>
#   <candidateId>
#    cfe34960-2a0e-11eb-83b1-25bddbcbae91
#   </candidateId>
#   <birthday>
#    1990
#   </birthday>
#   <gender>
#    Женский
#   </gender>
#   <retrainingCapability>
#    Готов к переобучению
#   </retrainingCapability>
#   <innerInfo>
#    <idUser>
#     ca3cafb0-520f-11e5-8696-1ff705945672
#    </idUser>
#    <status>
#     Одобрено
#    </status>
#    <visibility>
#     Видно всем
#    </visibility>
#    <dateModify>
#     2021-02-16
#    </dateModify>
#    <deleted>
#     false
#    </deleted>
#    <fullnessRate>
#     69
#    </fullnessRate>
#   </innerInfo>
#  </cv>
#  <cv about="http://opendata.trudvsem.ru/7710538364-cv/cv.xml#963949c0-6b73-11eb-b25a-e736a3d3ed84" typeof="Person">
#   <region rel="dc:references" resource="http://opendata.trudvsem.ru/7710538364-regions/regions.xml#3800000000000"/>
#   <profession rel="dc:references" resource="http://opendata.trudvsem.ru/7710538364-professions/professions.xml#242363"/>
#   <industry rel="dc:references" resource="http://opendata.trudvsem.ru/7710538364-industries/industries.xml#Education"/>
#   <positionName property="jobTitle">
#    Младший воспитатель
#   </positionName>
#   <creationDate>
#    2021-02-10
#   </creationDate>
#   <locality>
#    3801500500000
#   </locality>
#   <workExperienceList/>
#   <educationType>
#    Среднее
#   </educationType>
#   <educationList>
#    <educationType>
#     <graduateYear>
#      2016
#     </graduateYear>
#     <idOwner>
#      963949c0-6b73-11eb-b25a-e736a3d3ed84
#     </idOwner>
#     <type>
#      Education
#     </type>
#     <legalName>
#      Хребтовская общеобразовательная школа
#     </legalName>
#    </educationType>
#   </educationList>
#   <additionalEducationList/>
#   <worldskills>
#    <inspection_status>
#     Не применимо
#    </inspection_status>
#   </worldskills>
#   <competitions>
#    <abilympics/>
#   </competitions>
#   <qualification>
#    <nark/>
#   </qualification>
#   <driveLicenceList/>
#   <country>
#    <country_name>
#     Российская Федерация
#    </country_name>
#   </country>
#   <publishDate>
#    2021-02-10T10:56:30
#   </publishDate>
#   <scheduleTypesList>
#    <scheduleType>
#     Полный рабочий день
#    </scheduleType>
#   </scheduleTypesList>
#   <experience>
#    0
#   </experience>
#   <salary>
#    25000
#   </salary>
#   <busyType>
#    Полная занятость
#   </busyType>
#   <relocation>
#    Нет
#   </relocation>
#   <businessTrips>
#    Не готов к командировкам
#   </businessTrips>
#   <candidateId>
#    2031a610-669f-11eb-9893-7bf9d8e248ac
#   </candidateId>
#   <birthday>
#    2001
#   </birthday>
#   <gender>
#    Женский
#   </gender>
#   <retraining/>
#  </cv>
# </cvs>

# %% [markdown]
# Либо можем посмотреть кусок уже скаченного файла:

# %%
with open('resumes.xml', encoding='utf8') as fp:
    soup = BeautifulSoup(fp.read(1000), 'lxml-xml')
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <cvs vocab="http://schema.org/" xmlns:dc="http://purl.org/dc/terms/">
#  <cv about="http://opendata.trudvsem.ru/7710538364-cv/cv.xml#652be920-6f77-11eb-b531-ef76bd2a03c1" typeof="Person">
#   <region rel="dc:references" resource="http://opendata.trudvsem.ru/7710538364-regions/regions.xml#4200000000000"/>
#   <profession rel="dc:references" resource="http://opendata.trudvsem.ru/7710538364-professions/professions.xml#129014"/>
#   <industry rel="dc:references" resource="http://opendata.trudvsem.ru/7710538364-industries/industries.xml#Food"/>
#   <positionName property="jobTitle">
#    Кондитер
#   </positionName>
#   <creationDate>
#    2021-02-15
#   </creationDate>
#   <locality>
#    4200001200000
#   </locality>
#   <workExperienceList>
#    <workExperience>
#     <achievements>
#      &lt;p&gt;&lt;em&gt;изготовление конфет ручной работы, зефир, маршмелоу&lt;/em&gt;&lt;/p&gt;
#     </achievements>
#     <idOwner>
#      652be920-6f77-11eb-b531-ef76bd2a03c1
#     </idOwner>
#     <company_name>
#      ООО РОСТ
#     </company_name>
#     <dateTo>
#      2019-09-01T00:00:00+
#     </dateTo>
#    </workExperience>
#   </workExperienceList>
#  </cv>
# </cvs>

# %% [markdown]
# Для сбора в привычные пандасовские таблицы было принято решение использовать на Прекрасныйсуп, который просто не справляется с файлом такого объёма, а парсер lxml (которым Прекрасныйсуп и пользуется) с его методом iterparse. На первых этапах память тоже жёстко перегружалась и ядро умирало (точнее 4 или 8 ядер).

# %% [markdown]
# Решением стали очистка пройденного элемента и удаление построенного "куска xml-дерева" из памяти после каждого распарсенного элемента.

# %% [markdown]
#     elem.clear()
#     for ancestor in elem.xpath('ancestor-or-self::*'):
#             while ancestor.getprevious() is not None:
#                 del ancestor.getparent()[0]

# %% [markdown]
# В примере ниже распарсим только 1000 записей резюме. Но в случае последовательного сбора словарей, представляющих каждую будущую строку датафрейма {переменная: значение} постепенно опять сталкиваемся с перегрузкой памяти (при количестве более 1 млн записей, а их в современных дампах порядка 5 млн). Решением стала выгрузка части распарсенных записей в csv (по 500тыс). В принципе, можно сразу в БД выгружать, но у нас довольно обширная предобработка, так что мы собирали датафрейм из отдельных csv-файлов, обрабатывали и грузили в БД.

# %%
from lxml import etree
import pandas as pd
from tqdm import tqdm
df = pd.DataFrame()
# bar = tqdm() # Для большого количества записей можем воспользоваться счётчиком, сейчас только 1000 записей
i = 1
csv_size = 500000
l = []

start_time = time.time()
# Проходим по каждому элементу в файле
for event, elem in etree.iterparse('resumes.xml', tag='cv', recover=True):
    d = {}
    # И формируем словарик где ключ - имя элемента, а значение текст этого элемента
    d['about'] = elem.attrib['about'].rsplit('#', maxsplit=1)[-1]
    for element in list(elem): # Проходимся по каждому элементу в наборе
        if element.tag == 'profession':
            d['profession_code'] = element.attrib['resource'].rsplit('#', maxsplit=1)[-1]
            continue
        elif element.tag == 'region':
            d['region_code'] = element.attrib['resource'].rsplit('#', maxsplit=1)[-1]
            continue
        elif element.tag == 'industry':
            d['industry_code'] = element.attrib['resource'].rsplit('#', maxsplit=1)[-1]
            continue
        elif element.tag == 'workExperienceList' or element.tag == 'educationList' or element.tag == 'additionalEducationList':
            continue
        
        elif len(list(element)) >= 1: # Если длина значений этого элемента больше или равна 1, то перед нами словарь
            for sub_element in list(element):# По которому тоже нужно пройтись
                if sub_element.text != None:
                    d[element.tag + '_' + sub_element.tag] = sub_element.text
                    if len(list(sub_element)) >= 1: # Если длина значений этого элемента больше или равна 1, то перед нами словарь
                        for sub_sub_element in list(sub_element):# По которому тоже нужно пройтись
                            d[element.tag + '_' + sub_element.tag + '_' + sub_sub_element.tag] = sub_sub_element.text 
        elif element.text != None:
            d[element.tag] = element.text 
        else:
            continue
            
    elem.clear()
    for ancestor in elem.xpath('ancestor-or-self::*'):
            while ancestor.getprevious() is not None:
                del ancestor.getparent()[0] 
    l.append(d)# Добавим этот словарик в список
#     bar.update(n=1)# Увеличиваем счетчик на 1
    
    if len(l) == 1000:
        break

    if len(l) == csv_size: # Когда список станет достаточно большим
        df = pd.DataFrame(l)
        df.to_csv(f'../../../500000cv{i}.csv',index=False)
        break
        
        i = i + 1
        l = []# И очищаем список
        df = pd.DataFrame()# И очищаем датафрейм
print("--- %s seconds ---" % (time.time() - start_time))
# Не забыть сделать df из остатков и выгрузить его!
df = pd.DataFrame(l) 
# df.to_csv('../../../file_name.csv',index=False)
# Out:
# --- 0.13121461868286133 seconds ---

# %% [markdown]
# Можно прикинуть, что при количестве записей порядка 5 млн парсинг файла будет идти 10 минут. Добавьте время на загрузку, разархивацию, обработку, загрузку в БД и другие технические этапы.

# %%
df
# Out:
#                                     about    region_code profession_code  \
# 0    652be920-6f77-11eb-b531-ef76bd2a03c1  4200000000000          129014
# 1    963949c0-6b73-11eb-b25a-e736a3d3ed84  3800000000000          242363
# 2    0e71d3e9-c5db-11e7-aa78-037acc02728d  2300000000000          203369
# 3    d2b470e0-9839-11ea-9806-736ab11edb0c  3400000000000          114428
# 4    8b35ebb0-7f41-11ea-8d16-ef76bd2a03c1  3500000000000             NaN
# ..                                    ...            ...             ...
# 995  5247ffc0-8e20-11eb-8e20-6db06c9eaf56  8900000000000          277288
# 996  a9c0b7e0-01fb-11ea-9c5f-736ab11edb0c  5600000000000             NaN
# 997  91d213b0-04bf-11ea-9846-ef76bd2a03c1  3500000000000          241106
# 998  7db894f0-cb37-11ea-ba19-ab5d2eb93a75  1800000000000             NaN
# 999  14e40b00-eeb6-11eb-ba9c-ab5d2eb93a75  1800000000000             NaN
#
#              industry_code                                       positionName  \
# 0                     Food                                           Кондитер
# 1                Education                                Младший воспитатель
# 2                    Sales  Главный бухгалтер/Заместитель главного бухгалтера
# 3            StateServices                                           Водитель
# 4                 Medicine                                          Медсестра
# ..                     ...                                                ...
# 995          StateServices                                         Специалист
# 996                  Sales                                           Охранник
# 997  MechanicalEngineering                                            инженер
# 998                   Food                                    Техник-технолог
# 999                   Food                    Технолог пищевой промышленности
#
#     creationDate       locality             educationType  \
# 0     2021-02-15  4200001200000  Среднее профессиональное
# 1     2021-02-10  3801500500000                   Среднее
# 2     2017-11-10  2300000100000                    Высшее
# 3     2020-05-17  3403000100000                   Среднее
# 4     2020-04-15  3500000200000                       NaN
# ..           ...            ...                       ...
# 995   2021-03-26  8900000500000                    Высшее
# 996   2019-11-08  5600000500000                       NaN
# 997   2019-11-11  3500100000900                    Высшее
# 998   2020-07-21  1801300500000                       NaN
# 999   2021-07-27  1800000000000                       NaN
#
#     worldskills_inspection_status  country_country_name  ... innerInfo_status  \
# 0                    Не применимо  Российская Федерация  ...         Одобрено
# 1                    Не применимо  Российская Федерация  ...         Одобрено
# 2                    Не применимо  Российская Федерация  ...         Одобрено
# 3                    Не применимо  Российская Федерация  ...         Одобрено
# 4                    Не применимо  Российская Федерация  ...         Одобрено
# ..                            ...                   ...  ...              ...
# 995                  Не применимо  Российская Федерация  ...         Одобрено
# 996                  Не применимо  Российская Федерация  ...         Одобрено
# 997                  Не применимо  Российская Федерация  ...         Одобрено
# 998                  Не применимо  Российская Федерация  ...         Одобрено
# 999                  Не применимо  Российская Федерация  ...         Одобрено
#
#     innerInfo_visibility innerInfo_dateModify innerInfo_deleted  \
# 0             Видно всем           2021-02-16             false
# 1             Видно всем           2021-05-22             false
# 2             Видно всем           2021-06-21             false
# 3             Видно всем           2020-05-18             false
# 4             Видно всем           2021-07-31             false
# ..                   ...                  ...               ...
# 995           Видно всем           2021-10-12             false
# 996           Видно всем           2021-07-29             false
# 997           Видно всем           2019-12-12             false
# 998           Видно всем           2020-07-21             false
# 999           Видно всем           2021-07-27             false
#
#     innerInfo_fullnessRate driveLicenceList_driveLicences  \
# 0                       69                            NaN
# 1                       56                            NaN
# 2                       77                            [B]
# 3                       61                [A, B, C, D, E]
# 4                       53                            NaN
# ..                     ...                            ...
# 995                     84                            NaN
# 996                     48                            NaN
# 997                     80                            [B]
# 998                     49                            NaN
# 999                     48                            NaN
#
#                                                 skills  \
# 0                                                  NaN
# 1                                                  NaN
# 2    <p>Знание налогового и бухгалтерского учета на...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997  <p>Опыт руководящей работы на машиностроительн...
# 998                                                NaN
# 999                                                NaN
#
#                                       additionalSkills  \
# 0                                                  NaN
# 1                                                  NaN
# 2    <p>Внимательность, ответственность, коммуникаб...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997          <p>Настойчивость, целеустремленность.</p>
# 998                                                NaN
# 999                                                NaN
#
#                                              otherInfo  \
# 0                                                  NaN
# 1                                                  NaN
# 2    <p>Знание программ: 1С Предприятие Бухгалтерия...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                        addCertificates
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995  <p>&nbsp;Классный чин- референт муниципальной ...
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
# [1000 rows x 32 columns]

# %% [markdown]
# Общая информация по датафрейму

# %%
data = []
for column in df.columns.tolist():
    l = [column, df[column].isna().sum(), round(df[column].isna().sum() / df.shape[0] * 100, 1), df[column].notna().sum(), df[column].nunique()]
    data.append(l)
dfinfo = pd.DataFrame(data, columns = ['Name', 'NA', 'NA_share', 'Not_NA', 'Unique_values_count'])
dfinfo
# Out:
#                               Name   NA  NA_share  Not_NA  Unique_values_count
# 0                            about    0       0.0    1000                 1000
# 1                      region_code    0       0.0    1000                   81
# 2                  profession_code  560      56.0     440                  140
# 3                    industry_code    0       0.0    1000                   34
# 4                     positionName    0       0.0    1000                  588
# 5                     creationDate    0       0.0    1000                  506
# 6                         locality    1       0.1     999                  514
# 7                    educationType  241      24.1     759                    4
# 8    worldskills_inspection_status    0       0.0    1000                    2
# 9             country_country_name    0       0.0    1000                    3
# 10                     publishDate    0       0.0    1000                 1000
# 11  scheduleTypesList_scheduleType    0       0.0    1000                   29
# 12                      experience   66       6.6     934                   38
# 13                          salary    0       0.0    1000                   60
# 14                        busyType    0       0.0    1000                    5
# 15                      relocation  238      23.8     762                    2
# 16                   businessTrips  282      28.2     718                    2
# 17                     candidateId    0       0.0    1000                  865
# 18                        birthday   40       4.0     960                   46
# 19                          gender   37       3.7     963                    2
# 20            retrainingCapability  254      25.4     746                    2
# 21                innerInfo_idUser    1       0.1     999                  516
# 22                innerInfo_status    0       0.0    1000                    3
# 23            innerInfo_visibility    0       0.0    1000                    1
# 24            innerInfo_dateModify    0       0.0    1000                  431
# 25               innerInfo_deleted    0       0.0    1000                    1
# 26          innerInfo_fullnessRate    0       0.0    1000                   53
# 27  driveLicenceList_driveLicences  761      76.1     239                   11
# 28                          skills  699      69.9     301                  248
# 29                additionalSkills  645      64.5     355                  307
# 30                       otherInfo  916      91.6      84                   69
# 31                 addCertificates  939      93.9      61                   40
